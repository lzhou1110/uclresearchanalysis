# %%
import data_access
import pandas as pd

# %%
twi_nodes = pd.read_csv('Twi_nodes.csv')
twitter_ids = list(twi_nodes.Id)

# %%
dataAccessManager = data_access.DataAccess()
# Out:
# Initialted a total of 88 twitter api objects

# %%
dataAccessManager.get_existing_db_users(twitter_ids)
# Out:
#        contributors_enabled           created_at  \
# 0                         0  2010-11-11 03:59:09
# 1                         0  2009-04-22 22:44:05
# 2                         0  2008-11-02 17:07:55
# 3                         0  2009-04-03 01:03:15
# 4                         0  2011-09-26 21:58:16
# 5                         0  2009-01-14 21:32:04
# 6                         0  2010-11-29 15:23:21
# 7                         0  2010-06-08 16:33:07
# 8                         0  2010-01-23 22:17:51
# 9                         0  2008-12-04 14:49:42
# 10                        0  2010-06-03 05:06:52
# 11                        0  2010-12-02 22:26:54
# 12                        0  2009-01-29 10:52:20
# 13                        0  2009-11-08 01:52:32
# 14                        0  2009-02-02 21:15:09
# 15                        0  2010-05-29 15:03:35
# 16                        0  2010-06-22 16:57:06
# 17                        0  2008-11-17 04:37:27
# ...
