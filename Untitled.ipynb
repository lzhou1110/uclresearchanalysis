# %%
# %matplotlib inline
import config
from config import load_ml_data
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import *
from sklearn.metrics import *
from sklearn import svm
from pandas import *
import pandas as pd
from pprint import pprint
import sys

# %%
# Parameters
n_folds = 10
interval = 30

# 1. Prepare
def prepare_data(interval):
    df = load_ml_data(interval)
    df = df.sample(frac=0.1).reset_index(drop=True)
    
    # Converting all type to float, to prepare for feature selection
    df = df.astype('float')
    # Reset index, with drop equals to true to avoid setting old index as a new column
    df = df.reset_index(drop=True)
    # Visualize distribution
    print('[Original] data counts, with uninfected (0): {}, infected (1): {}'.format(
        df['label'].value_counts()[0],
        df['label'].value_counts()[1]
    ))
    df.groupby(['TwM_tCurrent','label']).size().unstack(fill_value=0).plot.bar(title='Original Data Distribution')
    
    columns = list(df.columns)
    columns.remove('label')
    
    X = df[columns]
    y = df[['label']]
    return df, X, y

# %%
# 1. Prepare
df, X, y = prepare_data(interval)
# Out:
# Loading data file from path /Users/lzhou/git/github/uclresearchanalysis/data/givenchy/pickle/30_data.dat
# 'Loaded 226984 entires'
# [Original] data counts, with uninfected (0): 4442, infected (1): 18256

# %%
len(X.columns)
# Out:
# 73

# %%
def train(df, X, y, model):
    # 2. N Fold Split
    # Stratified K-Folds cross-validator
    # Provides train/test indices to split data in train/test sets. 
    # This cross-validation object is a variation of KFold that returns stratified folds. 
    # The folds are made by preserving the percentage of samples for each class.
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)
    
    corrDataframe = pd.DataFrame()    
    mse = []
    acc = []
    roc = []
    acc_t = []
    fold_count = 0
    t_current = 210
#     number_of_features = len(X.columns)
    number_of_features = 60

    print("Start cross validation")
    for train, test in skf.split(X, y):
        print("===Processing fold %s===" % fold_count)
        train_fold = df.loc[train]
        test_fold = df.loc[test]

        # 3. Rebalance (Up-sampling)
        diff = sum(train_fold.label == 1) - sum(train_fold.label == 0)
        append_indices = np.random.choice(train_fold[train_fold.label == 0].index, diff, replace=True)
        new_sample = train_fold.loc[append_indices,:]
        train_fold = pd.concat([train_fold, new_sample])
        train_fold = train_fold.reset_index(drop=True)
        print('[Up-sampling] data counts, with uninfected (0): {}, infected (1): {}'.format(
            train_fold['label'].value_counts()[0],
            train_fold['label'].value_counts()[1],
        ))
        
        # 4. Feature Selection
        corr = train_fold.corr()['label'][train_fold.corr()['label'] < 1].abs()
        corr = corr.sort_values(ascending=False)
        corrDataframe = corrDataframe.append(pd.DataFrame(corr.rename('cv{}'.format(fold_count))).T)

        features = corr.index[range(number_of_features)].values
#         train_fold_input  = SelectKBest(chi2, k=50).fit_transform(train_fold[X.columns], train_fold['label'])

        train_fold_input = train_fold[features]
        train_fold_output = train_fold['label']
        
        # 5. Training
        # Fit logistic regression
        model.fit(train_fold_input, train_fold_output)

        # 6. Testing
        # Check MSE on test set
        test_fold_t = test_fold[test_fold.TwM_tCurrent == t_current]
        pred = model.predict(test_fold[features])
        pred_t = model.predict(test_fold_t[features])
        mse.append(mean_squared_error(test_fold.label, pred))
        acc.append(accuracy_score(test_fold.label, pred))
        roc.append(roc_auc_score(test_fold.label, pred))
        acc_t.append(accuracy_score(test_fold_t.label, pred_t))
        cm = confusion_matrix(test_fold.label, pred)
        print(cm)

        # Done with the fold
        fold_count += 1
    print("Finished cross validation")
    print("MSE: {} ".format(DataFrame(mse).mean()))
    print("ACC: {} ".format(DataFrame(acc).mean()))
    print("ROC: {} ".format(DataFrame(roc).mean()))
    print("ACC for t at {}: {} ".format(t_current, DataFrame(acc_t).mean()))
    corrDataframe = corrDataframe.T
    corrDataframe['average corr'] = corrDataframe.mean(numeric_only=True, axis=1)
    print(corrDataframe.sort_values(by=['average corr'], ascending=False).to_string())

# %%
# Linear Regression
# Random Forest
# Naive Bayes
# Logistic Regression
# Poisson Regression

# %%
# Logistic Regression
train(df, X, y, LogisticRegression())
# Out:
# Start cross validation
# ===Processing fold 0===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 361   84]
#  [ 451 1375]]
# ===Processing fold 1===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 355   90]
#  [ 466 1360]]
# ===Processing fold 2===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 359   85]
#  [ 436 1390]]
# ===Processing fold 3===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 366   78]
#  [ 460 1366]]
# ===Processing fold 4===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 374   70]
#  [ 473 1353]]
# ===Processing fold 5===
# [Up-sampling] data counts, with uninfected (0): 16430, infected (1): 16430
# [[ 361   83]
#  [ 436 1390]]
# ===Processing fold 6===
# [Up-sampling] data counts, with uninfected (0): 16431, infected (1): 16431
# [[ 355   89]
#  [ 421 1404]]
# ===Processing fold 7===
# [Up-sampling] data counts, with uninfected (0): 16431, infected (1): 16431
# [[ 355   89]
#  [ 439 1386]]
# ===Processing fold 8===
# [Up-sampling] data counts, with uninfected (0): 16431, infected (1): 16431
# [[ 364   80]
#  [ 425 1400]]
# ===Processing fold 9===
# [Up-sampling] data counts, with uninfected (0): 16431, infected (1): 16431
# [[ 358   86]
#  [ 433 1392]]
# Finished cross validation
# MSE: 0    0.232354
# dtype: float64
# ACC: 0    0.767646
# dtype: float64
# ROC: 0    0.784522
# dtype: float64
# ACC for t at 210: 0    0.493804
# dtype: float64
#                                                  cv0       cv1       cv2       cv3       cv4       cv5       cv6       cv7       cv8       cv9  average corr
# TwM_t0                                      0.619149  0.626386  0.620184  0.621686  0.620267  0.622516  0.624691  0.623855  0.622193  0.621397      0.622232
# TwM_tCurrent                                0.616807  0.624876  0.618239  0.619652  0.618077  0.620378  0.622357  0.621601  0.618803  0.619725      0.620051
# Stat_average_t                              0.605194  0.611721  0.606520  0.607161  0.606793  0.608163  0.610227  0.609060  0.608182  0.607058      0.608008
# TwM_t-1                                     0.533485  0.539527  0.534718  0.535804  0.535321  0.535499  0.538280  0.535597  0.535028  0.535262      0.535852
# UsM_favouritesCount-1                       0.006375  0.000531  0.011809  0.008694  0.008870  0.008197  0.002728  0.002632  0.007931  0.002151      0.005992
# Nw_inDegreeCentrality                       0.004992  0.006755  0.001587  0.004274  0.004064  0.005126  0.005984  0.011068  0.011465  0.001396      0.005671
# UsM_statusesCount-1                         0.001159  0.005230  0.004583  0.010133  0.011529  0.009598  0.005813  0.003208  0.000860  0.002175      0.005429
# UsM_normalizedUserFavouritesCount-1         0.005570  0.003113  0.010760  0.005539  0.007390  0.006551  0.001086  0.007026  0.006461  0.000036      0.005353
# UsM_normalizedUserFollowersCount            0.001479  0.005563  0.006818  0.003628  0.000266  0.001004  0.005412  0.013225  0.004698  0.002788      0.004488
# UsM_followersCount                          0.001985  0.000831  0.001035  0.000934  0.002311  0.006264  0.000669  0.007924  0.001220  0.001885      0.002506

# %%
# GBDT
train(df, X, y, GradientBoostingClassifier(n_estimators=150, learning_rate=0.1, min_samples_split=300,
                                  min_samples_leaf=20,max_depth=8,max_features='sqrt', subsample=0.8,random_state=10))
# Out:
# Start cross validation
# ===Processing fold 0===
# [Up-sampling] data counts, with uninfected (0): 9128, infected (1): 9128
# [[1707  514]
#  [1069 8059]]
# ===Processing fold 1===
# [Up-sampling] data counts, with uninfected (0): 9128, infected (1): 9128
# [[1683  538]
#  [1139 7989]]
# Finished cross validation
# MSE: 0    0.143625
# dtype: float64
# ACC: 0    0.856375
# dtype: float64
# ACC for t at 210: 0    0.584444
# dtype: float64
#                                             cv0 corr  cv1 corr  average corr
# TwM_t0                                      0.614071  0.631376      0.622723
# TwM_tCurrent                                0.610832  0.629654      0.620243
# Stat_average_t                              0.598730  0.616315      0.607522
# TwM_t-1                                     0.524565  0.545085      0.534825
# Nw_outDegreeCentrality-1                    0.193826  0.225908      0.209867
# Nw_degreeCentrality-1                       0.190232  0.222058      0.206145
# Stat_min_kOut                               0.182352  0.217547      0.199949
# Nw_betweennessCentrality-1                  0.176089  0.206779      0.191434
# Nw_inDegreeCentrality-1                     0.160126  0.189256      0.174691
# Stat_average_kOut                           0.151417  0.186092      0.168755
# UsM_friendsCount-1                          0.138994  0.163300      0.151147
# UsM_normalizedUserFriendsCount-1            0.135584  0.164713      0.150148
# Stat_average_friendsCount                   0.124950  0.151263      0.138107
# Nw_closenessCentrality-1                    0.130909  0.142247      0.136578
# Stat_average_normalizedUserFriendsCount     0.119303  0.148364      0.133833
# Nw_eigenvectorCentrality-1                  0.111396  0.134212      0.122804
# Nw_nNodes                                   0.088838  0.087344      0.088091
# Stat_average_deltaDays                      0.070678  0.087726      0.079202
# UsM_deltaDays-1                             0.062202  0.081270      0.071736
# Nw_averageNeighborDegree-1                  0.025328  0.073900      0.049614
# UsM_favouritesCount0                        0.057157  0.036151      0.046654
# UsM_normalizedUserListedCount-1             0.032868  0.058893      0.045881
# UsM_normalizedUserFavouritesCount0          0.055632  0.034072      0.044852
# Nw_averageNeighborDegree                    0.051255  0.037186      0.044221
# UsM_normalizedUserStatusesCount0            0.053030  0.030640      0.041835
# UsM_deltaDays                               0.038018  0.037130      0.037574
# UsM_listedCount-1                           0.021764  0.047424      0.034594
# Stat_average_normalizedUserStatusesCount    0.040450  0.019655      0.030052
# UsM_normalizedUserFollowersCount-1          0.022605  0.034302      0.028453
# Stat_average_statusesCount                  0.033582  0.022707      0.028144
# UsM_normalizedUserFollowersCount0           0.024503  0.030947      0.027725
# UsM_followersCount0                         0.023663  0.030932      0.027298
# UsM_friendsCount0                           0.016632  0.037333      0.026982
# Stat_average_normalizedUserListedCount      0.022825  0.030553      0.026689
# UsM_normalizedUserFriendsCount0             0.015159  0.037271      0.026215
# UsM_statusesCount0                          0.035549  0.016421      0.025985
# UsM_listedCount0                            0.021512  0.028826      0.025169
# Stat_average_favouritesCount                0.038116  0.012125      0.025120
# Nw_betweennessCentrality0                   0.010866  0.039238      0.025052
# UsM_normalizedUserListedCount0              0.021175  0.028207      0.024691
# Nw_inDegreeCentrality0                      0.011192  0.038017      0.024605
# UsM_followersCount-1                        0.017762  0.031143      0.024452
# Nw_degreeCentrality0                        0.009416  0.039475      0.024445
# UsM_friendsCount                            0.023907  0.024957      0.024432
# Nw_outDegreeCentrality0                     0.009060  0.039599      0.024330
# Nw_eigenvectorCentrality0                   0.009907  0.035386      0.022646
# Stat_average_listedCount                    0.017792  0.024690      0.021241
# Stat_average_normalizedUserFavouritesCount  0.032675  0.007469      0.020072
# Stat_average_normalizedUserFollowersCount   0.013398  0.018867      0.016132
# UsM_normalizedUserFavouritesCount           0.013047  0.018732      0.015890
# Nw_averageNeighborDegree0                   0.012525  0.017682      0.015104
# Nw_closenessCentrality0                     0.002097  0.027926      0.015011
# Nw_outDegreeCentrality                      0.012119  0.015748      0.013933
# Nw_eigenvectorCentrality                    0.008564  0.019302      0.013933
# Nw_inDegreeCentrality                       0.009375  0.018344      0.013860
# UsM_normalizedUserFriendsCount              0.021369  0.006248      0.013809
# Stat_average_followersCount                 0.011184  0.015882      0.013533
# UsM_normalizedUserListedCount               0.019573  0.007169      0.013371
# Nw_betweennessCentrality                    0.011182  0.014837      0.013009
# Nw_degreeCentrality                         0.008791  0.017115      0.012953
# Nw_closenessCentrality                      0.008851  0.016302      0.012577
# UsM_normalizedUserStatusesCount             0.015387  0.007391      0.011389
# UsM_deltaDays0                              0.016762  0.006008      0.011385
# Stat_max_kOut                               0.004380  0.018065      0.011222
# UsM_favouritesCount-1                       0.019889  0.000630      0.010259
# UsM_favouritesCount                         0.002427  0.017523      0.009975
# UsM_listedCount                             0.015654  0.004177      0.009915
# UsM_normalizedUserStatusesCount-1           0.012121  0.006024      0.009073
# UsM_normalizedUserFollowersCount            0.012262  0.005126      0.008694
# UsM_statusesCount-1                         0.008518  0.006466      0.007492
# UsM_statusesCount                           0.008501  0.005118      0.006810
# UsM_normalizedUserFavouritesCount-1         0.012168  0.001095      0.006632
# UsM_followersCount                          0.006854  0.006144      0.006499
