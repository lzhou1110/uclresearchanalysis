# %%
# %matplotlib inline
import config
from config import load_ml_data
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import *
from sklearn.metrics import *
from pandas import *
import pandas as pd

# %%
# Parameters
n_folds = 5
interval = 30

# 1. Prepare
def prepare_data(interval):
    df = load_ml_data(interval)
    # Converting all type to float, to prepare for feature selection
    df = df.astype('float')
    # Reset index, with drop equals to true to avoid setting old index as a new column
    df = df.reset_index(drop=True)
    # Visualize distribution
    print('[Original] data counts, with uninfected (0): {}, infected (1): {}'.format(
        df['label'].value_counts()[0],
        df['label'].value_counts()[1]
    ))
    df.groupby(['tCurrent','label']).size().unstack(fill_value=0).plot.bar(title='Original Data Distribution')
    
    columns = list(df.columns)
    columns.remove('label')
    
    X = df[columns]
    y = df[['label']]
    return df, X, y

# %%
# 1. Prepare
df, X, y = prepare_data(interval)
# Out:
# Loading data file from path /Users/taoguanyu/Workspace/uclresearchanalysis/data/givenchy/pickle/30_data.dat
# 'Loaded 226984 entires'
# [Original] data counts, with uninfected (0): 45869, infected (1): 181115

# %%
def train(df, X, y, model):
    # 2. N Fold Split

    # Stratified K-Folds cross-validator
    # Provides train/test indices to split data in train/test sets. 
    # This cross-validation object is a variation of KFold that returns stratified folds. 
    # The folds are made by preserving the percentage of samples for each class.
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)

    mse = []
    acc = []
    acc_t = []
    fold_count = 0
    t_current = 210

    print("Start cross validation")
    for train, test in skf.split(X, y):
        print("===Processing fold %s===" % fold_count)
        train_fold = df.loc[train]
        test_fold = df.loc[test]

        # 3. Rebalance (Up-sampling)
        diff = sum(train_fold.label == 1) - sum(train_fold.label == 0)
        append_indices = np.random.choice(train_fold[train_fold.label == 0].index, diff, replace=True)
        new_sample = train_fold.loc[append_indices,:]
        train_fold = pd.concat([train_fold, new_sample])
        train_fold = train_fold.reset_index(drop=True)
        print('[Up-sampling] data counts, with uninfected (0): {}, infected (1): {}'.format(
            train_fold['label'].value_counts()[0],
            train_fold['label'].value_counts()[1],
        ))
        # 4. Feature Selection
        corr = train_fold.corr()['label'][train_fold.corr()['label'] < 1].abs()
        corr = corr.sort_values(ascending=False)
        print(corr)
        features = corr.index[range(12)].values

        # 5. Training
        # Get training examples
        train_fold_input  = train_fold[features].values
        train_fold_output = train_fold['label']
        # Fit logistic regression
        model.fit(train_fold_input, train_fold_output)

        # 6. Testing
        # Check MSE on test set
        test_fold_t = test_fold[test_fold.tCurrent == t_current]
        pred = model.predict(test_fold[features])
        pred_t = model.predict(test_fold_t[features])
        mse.append(mean_squared_error(test_fold.label, pred))
        acc.append(accuracy_score(test_fold.label, pred))
        acc_t.append(accuracy_score(test_fold_t.label, pred_t))
        cm = confusion_matrix(test_fold.label, pred)
        print(cm)

        # Done with the fold
        fold_count += 1
    print("Finished cross validation")
    print("MSE: {} ".format(DataFrame(mse).mean()))
    print("ACC: {} ".format(DataFrame(acc).mean()))
    print("ACC for t at {}: {} ".format(t_current, DataFrame(acc_t).mean()))

# %%
# Logistic Regression
train(df, X, y, LogisticRegression(C=5.5))
# Out:
# Start cross validation
# ===Processing fold 0===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.624422
# tCurrent           0.622721
# tAverage           0.609697
# t-1                0.538339
# kOut-1             0.204142
# kOutMin            0.196135
# kOutAverage        0.170483
# nNodes             0.083881
# kOut0              0.027128
# deltaDays          0.027040
# friendsCount       0.021118
# kOutMax            0.006888
# followersCount     0.006542
# kIn                0.005783
# favouritesCount    0.003693
# statusesCount      0.003655
# listedCount        0.000971
# Name: label, dtype: float64
# [[ 7536  1638]
#  [ 8952 27271]]
# ===Processing fold 1===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.623744
# tCurrent           0.621977
# tAverage           0.608631
# t-1                0.536575
# kOut-1             0.207333
# kOutMin            0.200011
# kOutAverage        0.173413
# nNodes             0.080920
# kOut0              0.028903
# deltaDays          0.027903
# friendsCount       0.020297
# kOutMax            0.007898
# followersCount     0.006768
# statusesCount      0.006574
# favouritesCount    0.005311
# kIn                0.003856
# listedCount        0.000892
# Name: label, dtype: float64
# [[ 7544  1630]
#  [ 8909 27314]]
# ===Processing fold 2===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.625559
# tCurrent           0.623806
# tAverage           0.610511
# t-1                0.538757
# kOut-1             0.203898
# kOutMin            0.196040
# kOutAverage        0.169138
# nNodes             0.078544
# deltaDays          0.028898
# kOut0              0.025754
# friendsCount       0.019463
# kIn                0.006333
# favouritesCount    0.005203
# statusesCount      0.005149
# kOutMax            0.004489
# followersCount     0.003425
# listedCount        0.001366
# Name: label, dtype: float64
# [[ 7359  1815]
#  [ 8181 28042]]
# ===Processing fold 3===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.623319
# tCurrent           0.621687
# tAverage           0.609123
# t-1                0.538233
# kOut-1             0.205554
# kOutMin            0.197568
# kOutAverage        0.170634
# nNodes             0.079407
# deltaDays          0.025127
# kOut0              0.024907
# friendsCount       0.024561
# statusesCount      0.007783
# kOutMax            0.005892
# listedCount        0.005853
# kIn                0.004797
# favouritesCount    0.004040
# followersCount     0.002208
# Name: label, dtype: float64
# [[ 7512  1662]
#  [ 8992 27231]]
# ===Processing fold 4===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.624694
# tCurrent           0.623166
# tAverage           0.609866
# t-1                0.538165
# kOut-1             0.204917
# kOutMin            0.196842
# kOutAverage        0.170274
# nNodes             0.081469
# deltaDays          0.027237
# kOut0              0.026686
# friendsCount       0.023331
# kOutMax            0.009040
# statusesCount      0.007846
# favouritesCount    0.004546
# listedCount        0.004325
# followersCount     0.003520
# kIn                0.003417
# Name: label, dtype: float64
# [[ 7405  1768]
#  [ 8980 27243]]
# Finished cross validation
# MSE: 0    0.231413
# dtype: float64
# ACC: 0    0.768587
# dtype: float64
# ACC for t at 210: 0    0.513184
# dtype: float64

# %%
# GBDT
train(df, X, y, GradientBoostingClassifier(n_estimators=150, learning_rate=0.1, min_samples_split=300,
                                  min_samples_leaf=20,max_depth=8,max_features='sqrt', subsample=0.8,random_state=10))
# Out:
# Start cross validation
# ===Processing fold 0===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.622234
# tCurrent           0.620857
# tAverage           0.607329
# t-1                0.535606
# kOut-1             0.205967
# kOutMin            0.197661
# kOutAverage        0.171101
# nNodes             0.082920
# deltaDays          0.026702
# kOut0              0.026575
# friendsCount       0.023829
# statusesCount      0.007321
# kOutMax            0.007012
# kIn                0.005777
# favouritesCount    0.005056
# listedCount        0.004132
# followersCount     0.001440
# Name: label, dtype: float64
# [[ 8383   791]
#  [ 4527 31696]]
# ===Processing fold 1===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.624981
# tCurrent           0.622822
# tAverage           0.609893
# t-1                0.538028
# kOut-1             0.202601
# kOutMin            0.194748
# kOutAverage        0.167881
# nNodes             0.082723
# deltaDays          0.027843
# kOut0              0.023050
# friendsCount       0.020809
# statusesCount      0.006702
# followersCount     0.005209
# favouritesCount    0.004715
# kIn                0.004712
# kOutMax            0.004340
# listedCount        0.002910
# Name: label, dtype: float64
# [[ 8318   856]
#  [ 4555 31668]]
# ===Processing fold 2===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.624654
# tCurrent           0.622852
# tAverage           0.609063
# t-1                0.536719
# kOut-1             0.209751
# kOutMin            0.202597
# kOutAverage        0.176217
# nNodes             0.082101
# kOut0              0.029699
# deltaDays          0.029293
# friendsCount       0.017790
# kOutMax            0.010762
# kIn                0.007445
# statusesCount      0.005013
# followersCount     0.004438
# favouritesCount    0.002564
# listedCount        0.002450
# Name: label, dtype: float64
# [[ 8063  1111]
#  [ 5285 30938]]
# ===Processing fold 3===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.623444
# tCurrent           0.621777
# tAverage           0.609146
# t-1                0.538059
# kOut-1             0.206042
# kOutMin            0.198262
# kOutAverage        0.171296
# nNodes             0.082177
# deltaDays          0.026026
# kOut0              0.025477
# friendsCount       0.020293
# followersCount     0.005911
# kOutMax            0.004928
# kIn                0.004733
# statusesCount      0.004156
# favouritesCount    0.000425
# listedCount        0.000199
# Name: label, dtype: float64
# [[ 8305   869]
#  [ 4789 31434]]
# ===Processing fold 4===
# [Up-sampling] data counts, with uninfected (0): 144892, infected (1): 144892
# t0                 0.625244
# tCurrent           0.623657
# tAverage           0.610362
# t-1                0.538548
# kOut-1             0.207759
# kOutMin            0.199668
# kOutAverage        0.173719
# nNodes             0.078077
# kOut0              0.028848
# deltaDays          0.028238
# friendsCount       0.023154
# kOutMax            0.008987
# statusesCount      0.007838
# kIn                0.005368
# listedCount        0.005326
# favouritesCount    0.004212
# followersCount     0.004081
# Name: label, dtype: float64
# [[ 8065  1108]
#  [ 5109 31114]]
# Finished cross validation
# MSE: 0    0.127762
# dtype: float64
# ACC: 0    0.872238
# dtype: float64
# ACC for t at 210: 0    0.586446
# dtype: float64
